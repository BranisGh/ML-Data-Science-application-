# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import sys

# %%
pd.set_option('display.max_row', 111)
pd.set_option('display.max_column', 111)

# %% [markdown]
# ## 1. Statistiques descriptives
#
# ### Objectif :
# - Comprendre du mieux possible nos données (un petit pas en avant vaut mieux qu'un grand pas en arriere)
# - Développer une premiere stratégie de modélisation

# %%
full_path_directory = os.path.realpath(os.path.dirname('data/__file__'))
csv_name = 'data_v1.0.csv' 
data = pd.read_csv(os.path.join(full_path_directory, csv_name))
data.head()
# Out:
#    Unnamed: 0  index        date cheveux   age   exp  salaire sexe  diplome  \
# 0           0      0  2012-06-02    roux  25.0   9.0  26803.0    F  licence
# 1           1      1  2011-04-21   blond  35.0  13.0  38166.0    M  licence
# 2           2      2  2012-09-07   blond  29.0  13.0  35207.0    M  licence
# 3           3      3  2011-07-01    brun   NaN  12.0  32442.0    M  licence
# 4           4      4  2012-08-07    roux  35.0   6.0  28533.0    F  licence
#
#   specialite   note dispo  embauche
# 0   geologie  97.08   non         0
# 1     forage  63.86   non         0
# 2   geologie  78.50   non         0
# 3   geologie  45.09   non         0
# 4  detective  81.91   non         0

# %% [markdown]
# ### 1.1 Analyse du jeu de données

# %%
# Supprimer la premiere colone 'Unnamed: 0' et 'index' et 'date' car elles donnent aucune informations importantes
data = data.drop(['Unnamed: 0', 'index'], axis=1)
# Copier la dataset dans la variable df
df = data.copy()
print('Shape de la data : ', df.shape)
df.dtypes.value_counts()
# Out:
# Shape de la data :  (20000, 11)
# object     6
# float64    4
# int64      1
# dtype: int64

# %%
# Variables Qualitatives
for col in df.select_dtypes('object'):
    print(f'{col :-<50} {df[col].unique()}')
# Out:
# cheveux------------------------------------------- ['roux' 'blond' 'brun' 'chatain' nan]
# sexe---------------------------------------------- ['F' 'M' nan]
# diplome------------------------------------------- ['licence' 'master' 'doctorat' 'bac' nan]
# specialite---------------------------------------- ['geologie' 'forage' 'detective' 'archeologie' nan]
# dispo--------------------------------------------- ['non' 'oui' nan]

# %%
# Analyse des Nan
plt.figure(figsize=(20, 10))
sns.heatmap(df.isna(), cbar=False)
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# embauche      0.00000
# date          0.00455
# age           0.00455
# specialite    0.00465
# salaire       0.00475
# exp           0.00480
# sexe          0.00500
# cheveux       0.00515
# dispo         0.00530
# diplome       0.00550
# note          0.00570
# dtype: float64

# %% [markdown]
# ### Checklist de base
# #### Analyse de Forme :
# - **Variable target** : embauche
# - **Lignes et colonnes** : 20000, 11
# - **Types de variables** : qualitatives : 6, quantitatives : 5
# - **Analyse des valeurs manquantes** :
#     - Pas beaucoup de NaN (Presque toutes les features posèdent 0.5% de NaN en moyenne)
#     - Quelques featurs qui pourai avoir des lien entre eux (exp, age), (speciatite, salaire, exp), (sexe, cheuveux), (diplome, note)
#
# - **Variables à sélectionner en vue de la prédiction du succès ou de l’échec d’une candidature**
#     - exp
#     - speciatite
#     - diplome
#     - note
#     - salaire
#     - sexe

# %% [markdown]
# ## Relation target avec les autres variables

# %%
# On creer deux sous-ensembles
embauche_df = df[df['embauche'] == 1]
non_embauche_df = df[df['embauche'] == 0]

# %%
# Relation entre target et variable quantitatives
for col in df.select_dtypes('float64','int64'):
    plt.figure()
    sns.histplot(embauche_df[col], label='embauche', color="red", kde=True)
    sns.histplot(non_embauche_df[col], label='non embauche', color="blue",kde=True)
    plt.legend()

# %% [markdown]
# **Remarque** :
# Toute les variables sité en haut, ont une grande influence sur le target.

# %%
# Supprimer la colone 'date' car elle ne donne pas d'informations pertinentes
df = df.drop(['date'], axis=1)

# %%
# Relation entre target et variable qualitatives
for col in df.select_dtypes('object'):
    plt.figure()
    sns.heatmap(pd.crosstab(df['embauche'], df[col]), annot=True, fmt='d')

# %% [markdown]
# **Remarque** :
# - Cheuveux : Pas de differences
# - sexe : Masculin plus embauché
# - diplome : important pour l'embauche
# - spetialité : geologie beaucoup d'embauche
# - dispo : plus d'embauche pour le 'non'

# %% [markdown]
# ## 2. Dépendance statistiquement significative entre variables :
# ### 2.1 La spéecialité et le sexe

# %%
pd.crosstab(df['specialite'], df['sexe'])
# Out:
# sexe            F     M
# specialite
# archeologie  1081   298
# detective    2522  1614
# forage       1964  2351
# geologie     2403  7576

# %% [markdown]
# **Remarque** :
# - archeologie : beaucoup de femmes par rapport au hommes
# - geologie : beaucoup d'hommes par rapport au femmes

# %% [markdown]
# ### 2.2 La couleur de cheveux et le salaire demandé

# %%
plt.figure()
for cat in df['cheveux'].unique():
    sns.distplot(df[df['cheveux']==cat]['salaire'], label=cat)
plt.legend()
# Out:
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\louna\anaconda3\lib\site-packages\seaborn\distributions.py:2657: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# c:\Users\louna\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\louna\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# **Remarque** : On voit bien sur ce graphe que il n y a aucun decalage, donc les deux variables sont independantes.

# %% [markdown]
# ### 2.3 Le nombre d’années d’expérience et la note à l’exercice

# %%
plt.figure()
sns.lmplot(x='exp', y='salaire', hue='embauche', data=df)

# %%
print("La correlation entre les deux : ",df['exp'].corr(df['salaire']))
# Out:
# La correlation entre les deux :  0.009709424525642558

# %% [markdown]
# **Remarque** : Depuis le graphe on voit les deux droites lineaires l'une sur l'autres.
# et la correlation entre ces deux varaibles est tres faibles.
# Donc il y'a pas de liens entre ces deux dernieres.
